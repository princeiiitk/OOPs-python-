# %% [markdown]
# <a href="https://colab.research.google.com/github/princeiiitk/OOPs-python-/blob/main/CampusX_OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Bank:
  def __init__(self):
    self.userName=''
    self.balance=0

# %%
SBI=Bank()

# %%
print(type(SBI))
# Out:
# <class '__main__.Bank'>
